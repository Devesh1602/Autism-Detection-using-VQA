# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/video_features_TD12.csv')

# %%
data
# Out:
#        FaceRectX   FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0     707.609049  165.982853     114.994683      142.912800   0.998912
# 1     707.609049  165.982853     114.994683      142.912800   0.998912
# 2     708.577908  168.710020     113.120117      140.438524   0.998621
# 3     708.305990  168.137598     113.925130      141.778685   0.998800
# 4     708.506565  167.563271     114.471571      142.356892   0.999080
# ...          ...         ...            ...             ...        ...
# 3256  706.547472  175.417809     113.971842      147.987453   0.998080
# 3257  706.417209  175.181534     114.223416      148.250336   0.998072
# 3258  706.417209  175.181534     114.223416      148.250336   0.998072
# 3259  706.708388  173.739424     114.617459      150.295149   0.997001
# 3260  707.314399  174.870432     113.877604      147.873968   0.998217
#
#              x_0         x_1         x_2         x_3         x_4  ...  \
# ...

# %%
l1 = []

# %%
for i in range(0,len(data)):
  if data['AU06'][i]> 0.191667 and data['AU12'][i]>0.141667:
    l1.append("yes")
  else:
    l1.append("no")
data['Are there signs of Unusual/ excessive smiling?'] = l1
l1 = []
for i in range(0,len(data)):
  if data['AU43'][i]> 0.216667 and data['AU06'][i]> 0.191667 and data['AU09'][i]> 0.15:
    l1.append("yes")
  else:
    l1.append("no")
data['Is the face asymmetric(FA)?'] = l1
l1 = []
for i in range(0,len(data)):
  if(data['AU25'][i]> 0.333333 and data['AU26'][i]> 0.15):
    l1.append("yes")
  else:
    l1.append("no")
data['Are their lips parted?'] = l1
l1 = []
for i in range(0,len(data)):
  if data['AU06'][i]>0.191667:
    l1.append("yes")
  else:
    l1.append("no")
data['Are cheeks puffed or raised with happiness?'] = l1
l1 = []
for i in range(0,len(data)):
  if data['AU20'][i]> 0.083333:
    l1.append("yes")
  else:
    l1.append("no")
data['Are there any noticeable lip movements, (such as lip pursing, biting, or smacking, exhibited by the child in the video) ?'] = l1
l1 = []
for i in range(0,len(data)):
  if data['AU15'][i]> 0.4:
    l1.append("yes")
  else:
    l1.append("no")
data['Does the lip corner depressor show discomfort or stress?'] = l1
l1 = []
for i in range(0,len(data)):
  if(data['AU25'][i]> 0.333333 and data['AU26'][i]> 0.15):
    l1.append("yes")
  else:
    l1.append("no")
data['Are there signs of jaw clenching or teeth grinding?'] = l1
l1 = []
for i in range(0,len(data)):
  if(data['AU43'][i]> 0.216667):
    l1.append("yes")
  else:
    l1.append("no")
data[' Does the child have reduced eye contact?'] = l1
l1 = []
for i in range(0,len(data)):
  if(data['AU43'][i]> 0.216667):
    l1.append("yes")
  else:
    l1.append("no")
data['Does the child have atypical gaze patterns?'] = l1
l1 = []
for i in range(0,len(data)):
  if(data['AU04'][i]> 0.216667):
    l1.append("yes")
  else:
    l1.append("no")
data['Are the inner portions of the brows furrowed horizontally?'] = l1
l1 = []
for i in range(0,len(data)):
  if(data['AU01'][i]>0.491667):
    l1.append("yes")
  else:
    l1.append("no")
data['Is there absence of the inner brow raiser?'] = l1

# %%
data
# Out:
#        FaceRectX   FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0     707.609049  165.982853     114.994683      142.912800   0.998912
# 1     707.609049  165.982853     114.994683      142.912800   0.998912
# 2     708.577908  168.710020     113.120117      140.438524   0.998621
# 3     708.305990  168.137598     113.925130      141.778685   0.998800
# 4     708.506565  167.563271     114.471571      142.356892   0.999080
# ...          ...         ...            ...             ...        ...
# 3256  706.547472  175.417809     113.971842      147.987453   0.998080
# 3257  706.417209  175.181534     114.223416      148.250336   0.998072
# 3258  706.417209  175.181534     114.223416      148.250336   0.998072
# 3259  706.708388  173.739424     114.617459      150.295149   0.997001
# 3260  707.314399  174.870432     113.877604      147.873968   0.998217
#
#              x_0         x_1         x_2         x_3         x_4  ...  \
# ...

# %%
data.to_csv('feature12.csv')
