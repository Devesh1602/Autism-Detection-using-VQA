# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/bmc2.csv')

# %%
data
# Out:
#        FaceRectX   FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0     865.570692  336.203133     317.611057      407.807968   0.998354
# 1     865.890245  333.035362     319.283474      412.016899   0.998237
# 2     865.740994  334.909630     317.141819      408.372253   0.997989
# 3     863.868815  334.156792     313.655382      410.975189   0.998086
# 4     864.068142  331.252728     308.735243      410.773899   0.998166
# ...          ...         ...            ...             ...        ...
# 1385  955.890734  329.181942     317.982964      408.483799   0.996393
# 1386  948.107856  341.820992     316.554253      407.752556   0.996157
# 1387  947.277669  340.831570     318.305013      409.080357   0.995794
# 1388  947.097005  342.439453     319.181207      405.087547   0.995722
# 1389  949.306641  345.048878     316.355252      399.636990   0.996680
#
#              x_0         x_1         x_2         x_3         x_4  ...  \
# 0     859.437006  864.554202  873.272245  885.788089  905.461516  ...
# 1     856.599958  862.850322  872.695581  885.721312  905.220978  ...
# 2     855.189773  861.477001  871.240480  884.175150  903.595056  ...
# 3     855.206640  861.090611  870.471204  883.376778  902.641975  ...
# 4     851.017937  858.243559  868.302964  881.814315  901.802886  ...
# ...          ...         ...         ...         ...         ...  ...
# 1385  948.038917  951.542771  958.343730  968.663875  985.946973  ...
# 1386  952.325526  956.326760  963.304073  973.169388  990.193857  ...
# 1387  951.226396  955.393790  962.488553  972.388618  989.453406  ...
# 1388  951.975884  955.991472  963.117106  973.159196  990.286696  ...
# 1389  952.400745  956.519309  963.526148  973.279885  990.274396  ...
#
#           AU43     anger   disgust      fear  happiness   sadness  surprise  \
# 0     0.134147  0.351344  0.002122  0.002437   0.005787  0.360904  0.000463
# 1     0.152491  0.344311  0.002641  0.001909   0.002899  0.449838  0.000355
# 2     0.150725  0.401311  0.003276  0.002688   0.004147  0.352803  0.000700
# 3     0.662418  0.363627  0.002170  0.002040   0.003688  0.440726  0.000604
# 4     0.453664  0.438016  0.005391  0.002541   0.003323  0.324187  0.000677
# ...        ...       ...       ...       ...        ...       ...       ...
# 1385  0.166332  0.245433  0.001485  0.003738   0.019719  0.093912  0.002685
# 1386  0.208177  0.502651  0.000757  0.001361   0.003120  0.046070  0.000673
# 1387  0.131733  0.509219  0.000674  0.002093   0.001647  0.085060  0.000581
# 1388  0.184203  0.463511  0.000629  0.001471   0.002408  0.107825  0.000557
# 1389  0.158188  0.413544  0.001480  0.002351   0.003887  0.119123  0.001218
#
#        neutral                        input  frame
# 0     0.276944     /content/data/frame0.jpg      0
# 1     0.198046     /content/data/frame1.jpg      0
# 2     0.235074     /content/data/frame2.jpg      0
# 3     0.187144     /content/data/frame3.jpg      0
# 4     0.225865     /content/data/frame4.jpg      0
# ...        ...                          ...    ...
# 1385  0.633028  /content/data/frame1324.jpg      0
# 1386  0.445368  /content/data/frame1325.jpg      0
# 1387  0.400726  /content/data/frame1326.jpg      0
# 1388  0.423599  /content/data/frame1327.jpg      0
# 1389  0.458396  /content/data/frame1328.jpg      0
#
# [1390 rows x 173 columns]

# %%
l1 = []

# %%
for i in range(0,len(data)):
  if data['AU06'][i]<0.5 and data['AU12'][i]<0.5 :
    l1.append("yes")
  else:
    l1.append("no")
data['Are there signs of Unusual/ excessive smiling?'] = l1
l1 = []
for i in range(0,len(data)):
  if data['AU43'][i]>0.2 and data['AU06'][i]<0.5 and 0.2<data['AU09'][i]<0.6:
    l1.append("yes")
  else:
    l1.append("no")
data['Is the face asymmetric(FA)?'] = l1
l1 = []
for i in range(0,len(data)):
  if(0.5>data['AU25'][i] and 0.5>data['AU26'][i]):
    l1.append("yes")
  else:
    l1.append("no")
data['Are their lips parted?'] = l1
l1 = []
for i in range(0,len(data)):
  if 0.5>data['AU06'][i]:
    l1.append("yes")
  else:
    l1.append("no")
data['Are cheeks puffed or raised with happiness?'] = l1
l1 = []
for i in range(0,len(data)):
  if data['AU20'][i] == 0:
    l1.append("yes")
  else:
    l1.append("no")
data['Are there any noticeable lip movements, (such as lip pursing, biting, or smacking, exhibited by the child in the video) ?'] = l1
l1 = []
for i in range(0,len(data)):
  if 0.4 > data['AU15'][i]:
    l1.append("yes")
  else:
    l1.append("no")
data['Does the lip corner depressor show discomfort or stress?'] = l1
l1 = []
for i in range(0,len(data)):
  if(0.5>data['AU25'][i] and 0.5>data['AU26'][i]):
    l1.append("yes")
  else:
    l1.append("no")
data['Are there signs of jaw clenching or teeth grinding?'] = l1
l1 = []
for i in range(0,len(data)):
  if(0.3<data['AU43'][i]):
    l1.append("yes")
  else:
    l1.append("no")
data[' Does the child have reduced eye contact?'] = l1
l1 = []
for i in range(0,len(data)):
  if(0.3<data['AU43'][i]):
    l1.append("yes")
  else:
    l1.append("no")
data['Does the child have atypical gaze patterns?'] = l1
l1 = []
for i in range(0,len(data)):
  if(0.4<data['AU04'][i]):
    l1.append("yes")
  else:
    l1.append("no")
data['Are the inner portions of the brows furrowed horizontally?'] = l1
l1 = []
for i in range(0,len(data)):
  if(0.45<data['AU01'][i]):
    l1.append("yes")
  else:
    l1.append("no")
data['Is there absence of the inner brow raiser?'] = l1

# %%
data
# Out:
#        FaceRectX   FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0     865.570692  336.203133     317.611057      407.807968   0.998354
# 1     865.890245  333.035362     319.283474      412.016899   0.998237
# 2     865.740994  334.909630     317.141819      408.372253   0.997989
# 3     863.868815  334.156792     313.655382      410.975189   0.998086
# 4     864.068142  331.252728     308.735243      410.773899   0.998166
# ...          ...         ...            ...             ...        ...
# 1385  955.890734  329.181942     317.982964      408.483799   0.996393
# 1386  948.107856  341.820992     316.554253      407.752556   0.996157
# 1387  947.277669  340.831570     318.305013      409.080357   0.995794
# 1388  947.097005  342.439453     319.181207      405.087547   0.995722
# 1389  949.306641  345.048878     316.355252      399.636990   0.996680
#
#              x_0         x_1         x_2         x_3         x_4  ...  \
# 0     859.437006  864.554202  873.272245  885.788089  905.461516  ...
# 1     856.599958  862.850322  872.695581  885.721312  905.220978  ...
# 2     855.189773  861.477001  871.240480  884.175150  903.595056  ...
# 3     855.206640  861.090611  870.471204  883.376778  902.641975  ...
# 4     851.017937  858.243559  868.302964  881.814315  901.802886  ...
# ...          ...         ...         ...         ...         ...  ...
# 1385  948.038917  951.542771  958.343730  968.663875  985.946973  ...
# 1386  952.325526  956.326760  963.304073  973.169388  990.193857  ...
# 1387  951.226396  955.393790  962.488553  972.388618  989.453406  ...
# 1388  951.975884  955.991472  963.117106  973.159196  990.286696  ...
# 1389  952.400745  956.519309  963.526148  973.279885  990.274396  ...
#
#       Is the face asymmetric(FA)?  Are their lips parted?  \
# 0                              no                     yes
# 1                              no                     yes
# 2                              no                     yes
# 3                             yes                     yes
# 4                             yes                     yes
# ...                           ...                     ...
# 1385                           no                     yes
# 1386                          yes                     yes
# 1387                           no                     yes
# 1388                           no                     yes
# 1389                           no                     yes
#
#       Are cheeks puffed or raised with happiness?  \
# 0                                             yes
# 1                                             yes
# 2                                             yes
# 3                                             yes
# 4                                             yes
# ...                                           ...
# 1385                                          yes
# 1386                                          yes
# 1387                                          yes
# 1388                                          yes
# 1389                                          yes
#
#       Are there any noticeable lip movements, (such as lip pursing, biting, or smacking, exhibited by the child in the video) ?  \
# 0                                                   yes
# 1                                                   yes
# 2                                                   yes
# 3                                                   yes
# 4                                                   yes
# ...                                                 ...
# 1385                                                yes
# 1386                                                yes
# 1387                                                yes
# 1388                                                yes
# 1389                                                yes
#
#       Does the lip corner depressor show discomfort or stress?  \
# 0                                                   yes
# 1                                                   yes
# 2                                                   yes
# 3                                                   yes
# 4                                                   yes
# ...                                                 ...
# 1385                                                yes
# 1386                                                yes
# 1387                                                yes
# 1388                                                yes
# 1389                                                yes
#
#       Are there signs of jaw clenching or teeth grinding?  \
# 0                                                   yes
# 1                                                   yes
# 2                                                   yes
# 3                                                   yes
# 4                                                   yes
# ...                                                 ...
# 1385                                                yes
# 1386                                                yes
# 1387                                                yes
# 1388                                                yes
# 1389                                                yes
#
#        Does the child have reduced eye contact?  \
# 0                                            no
# 1                                            no
# 2                                            no
# 3                                           yes
# 4                                           yes
# ...                                         ...
# 1385                                         no
# 1386                                         no
# 1387                                         no
# 1388                                         no
# 1389                                         no
#
#       Does the child have atypical gaze patterns?  \
# 0                                              no
# 1                                              no
# 2                                              no
# 3                                             yes
# 4                                             yes
# ...                                           ...
# 1385                                           no
# 1386                                           no
# 1387                                           no
# 1388                                           no
# 1389                                           no
#
#       Are the inner portions of the brows furrowed horizontally?  \
# 0                                                    no
# 1                                                    no
# 2                                                    no
# 3                                                    no
# 4                                                    no
# ...                                                 ...
# 1385                                                yes
# 1386                                                 no
# 1387                                                 no
# 1388                                                 no
# 1389                                                yes
#
#       Is there absence of the inner brow raiser?
# 0                                             no
# 1                                             no
# 2                                             no
# 3                                             no
# 4                                             no
# ...                                          ...
# 1385                                          no
# 1386                                          no
# 1387                                          no
# 1388                                          no
# 1389                                          no
#
# [1390 rows x 184 columns]

# %%
data.to_csv('video_threshold.csv')
